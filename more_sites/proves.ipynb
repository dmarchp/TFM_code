# %%
import numpy as np
import pandas as pd
import sys
sys.path.append('../')
from package_global_functions import *

extSSDpath = getExternalSSDpath()
if os.path.exists(extSSDpath):
    path = extSSDpath + getProjectFoldername() + '/more_sites/results'
else:
    path = '/results'

# %%
Nsites = 3
resFile = f'results_int_Nsites_{Nsites}.csv'
df = pd.read_csv(path + '/' + resFile)

# %%
df.query("ic == 'N'")
# Out:
#     pi1  pi2  pi3   q1   q2    q3     l        f0        f1        f2  \
# 0   0.1  0.1  0.1  5.0  7.0  10.0  0.00  0.312500  0.156250  0.218750
# 1   0.1  0.1  0.1  5.0  7.0  10.0  0.05  0.296685  0.152215  0.220156
# 2   0.1  0.1  0.1  5.0  7.0  10.0  0.10  0.280945  0.147087  0.220325
# 3   0.1  0.1  0.1  5.0  7.0  10.0  0.15  0.265411  0.140834  0.218932
# 4   0.1  0.1  0.1  5.0  7.0  10.0  0.20  0.250205  0.133479  0.215657
# 5   0.1  0.1  0.1  5.0  7.0  10.0  0.25  0.235441  0.125111  0.210224
# 6   0.1  0.1  0.1  5.0  7.0  10.0  0.30  0.221225  0.115883  0.202455
# 7   0.1  0.1  0.1  5.0  7.0  10.0  0.35  0.207652  0.106010  0.192327
# 8   0.1  0.1  0.1  5.0  7.0  10.0  0.40  0.194808  0.095747  0.180005
# 9   0.1  0.1  0.1  5.0  7.0  10.0  0.45  0.182760  0.085360  0.165831
# 10  0.1  0.1  0.1  5.0  7.0  10.0  0.50  0.171554  0.075096  0.150274
# 11  0.1  0.1  0.1  5.0  7.0  10.0  0.55  0.161203  0.065154  0.133851
# 12  0.1  0.1  0.1  5.0  7.0  10.0  0.60  0.151697  0.055678  0.117052
# 13  0.1  0.1  0.1  5.0  7.0  10.0  0.65  0.143000  0.046754  0.100287
# 14  0.1  0.1  0.1  5.0  7.0  10.0  0.70  0.135063  0.038423  0.083867
# 15  0.1  0.1  0.1  5.0  7.0  10.0  0.75  0.127825  0.030688  0.068008
# 16  0.1  0.1  0.1  5.0  7.0  10.0  0.80  0.121223  0.023534  0.052845
# 17  0.1  0.1  0.1  5.0  7.0  10.0  0.85  0.115196  0.016927  0.038450
# 18  0.1  0.1  0.1  5.0  7.0  10.0  0.90  0.109685  0.010830  0.024849
# 19  0.1  0.1  0.1  5.0  7.0  10.0  0.95  0.104636  0.005201  0.012040
#
#           f3 ic
# 0   0.312500  N
# 1   0.330944  N
# 2   0.351643  N
# 3   0.374823  N
# 4   0.400658  N
# 5   0.429224  N
# 6   0.460438  N
# 7   0.494011  N
# 8   0.529441  N
# 9   0.566049  N
# 10  0.603077  N
# 11  0.639791  N
# 12  0.675573  N
# 13  0.709958  N
# 14  0.742647  N
# 15  0.773479  N
# 16  0.802398  N
# 17  0.829427  N
# 18  0.854636  N
# 19  0.878123  N
