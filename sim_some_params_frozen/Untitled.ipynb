# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('other_res_files/MeanClusterSize_v0_nopush_N_492_ar_75.0_er_1.5.csv')

# %%
df.sort_values(by='interac_r', inplace=True)

# %%
fig, ax = plt.subplots()
ax.plot(df['interac_r'], df['mcs'])
