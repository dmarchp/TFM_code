# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.optimize import curve_fit, brentq
from scipy import integrate
from scipy.stats import linregress
from scipy.stats import gaussian_kde
from scipy.ndimage import gaussian_filter

import matplotlib
from matplotlib import colors
from matplotlib.ticker import NullFormatter

from mpl_toolkits.axes_grid1.inset_locator import InsetPosition
from mpl_toolkits.axes_grid1 import AxesGrid
# Out:
# /home/david/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
plt.figure(figsize=(7, 7))
plt.axvline(0., color='k', linewidth=1)
plt.arrow(0, 6.5, 0, 0.01, color='k', head_width=0.5, head_length=0.5)
plt.axhline(0, color='k', linewidth=1)
plt.arrow(9.5, 0, 0.01, 0, color='k', head_width=0.5, head_length=0.5)
plt.xlim([-10, 10])
plt.ylim([-10, 7])
plt.axis('off')

plus = np.arctan(0.5)
plt.arrow(0, 0, 4.*np.cos(plus), 4.*np.sin(plus), color='C0', linewidth=2, linestyle=(0, (3, 3)))
plt.arrow(4.*np.cos(plus), 4.*np.sin(plus), 0.01*4.*np.cos(plus), 0.01*4.*np.sin(plus),
          color='C0', head_width=0.5, head_length=0.5)

plus2 = np.arctan(0.5 - 1.2)
plt.arrow(0, 0, 4.*np.cos(plus2), 4.*np.sin(plus2), color='C0', linewidth=2)
plt.arrow(4.*np.cos(plus2), 4.*np.sin(plus2), 0.01*4.*np.cos(plus2), 0.01*4.*np.sin(plus2),
          color='C0', head_width=0.5, head_length=0.5)
circ = mpatches.Wedge((0, 0), 2.5, 360 + plus2*180./np.pi, plus*180./np.pi,
                      fill=True, color='C0', alpha=0.7, zorder=0)
plt.gca().add_patch(circ)

# %%
plt.figure(figsize=(7, 7))
plt.xlim([-10, 10])
plt.ylim([-10, 10])
plt.axis('off')

circle = mpatches.Circle((0,0), 1)
plt.gca().add_patch(circle)

circle = mpatches.Circle((0,6), 1)
plt.gca().add_patch(circle)

arc=mpatches.FancyArrowPatch((np.sqrt(0.5),np.sqrt(0.5)), (1,6))
plt.gca().add_patch(arc)
