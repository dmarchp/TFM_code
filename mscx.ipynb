# %%
import matplotlib.pyplot as plt
import sys
from subprocess import call
sys.path.append('./')
from package_global_functions import *
latexFont(titlesize=11, ticklabelssize=11, labelsize=13, legendsize=12)

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5), constrained_layout=True)

infoMedia = ['Word of mouth', 'Radio', 'TV', 'Social Media']
counts = [871, 1221, 251, 106]
# bar_colors = plt.cm.twilight_shifted(np.linspace(0,1,len(infoMedia)))
bar_colors = plt.cm.Set2(np.linspace(0,1,len(infoMedia)))

# ax.bar(infoMedia, counts, color=bar_colors)
# ax.pie(counts, labels=infoMedia, colors=bar_colors, autopct='%1.1f%%')
ax.pie(counts, colors=bar_colors, autopct='%1.1f%%')

# ax.set_ylabel('')
# plt.tick_params('x', labelsize=14)
# ax.set_title('Supply of information in rural Madagascar', fontsize=16)
fig.savefig('madagascar_info.png')

# %%
# number of facebook users
latexFont(titlesize=11, ticklabelssize=11, labelsize=16, legendsize=12)

fig, ax = plt.subplots(1,1, figsize=(6,6), constrained_layout=True)

year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
users = [0.8, 1.1, 1.4, 1.7, 2.0, 2.3, 2.6, 3.0, 3.4, 3.8]

ax.plot(year, users, marker='o', mfc='white', ms=8, color='xkcd:blue')
ax.grid(which='major', axis='y', ls=':', color='xkcd:light gray')
ax.set(xlabel='Year', ylabel='Million Users')

fig.savefig('madagascar_fbusers.png')
